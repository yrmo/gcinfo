# %%
import gcinfo

# %%
gcinfo.search_titles(organization="cbsa-asfc", rows=100)
# Out:
# Directory of CBSA Offices
# Single Window Initiative, Integrated Import Declaration (IID) - Regulated Commodities - Data Element Matching Criteria Table
# Border Wait Times – Air Mode
# Algorithmic Impact Assessment - Client Reporting and Engagement System (CRES)/ReportIn
# Traveller volumes by port of entry and month
# Historical Border Wait Times – Land Mode
# Algorithmic Impact Assessment - CBSA Assessment and Revenue Management (CARM)
# Algorithmic Impact Assessment - Export Compliance Dashboard
# CBSA Access to Information – Annual Statistics
# CBSA Privacy – Annual Statistics
# National Administrative Monetary Penalty (AMPS) Statistics
# Open Government Implementation Plan - Canada Border Services Agency
# Information for people detained under the Immigration and Refugee Protection Act
# What you need to know about customs controlled areas
# Accelerated Commercial Release Operations Support System (ACROSS) Error Codes
# Removals Processed by Region by Year
# ...

# %%
gcinfo.search_titles(organization="cic", rows=100)
# Out:
# Asylum Claimants – Monthly IRCC Updates
# Express Entry-Invited Candidates – Monthly IRCC Updates
# Permanent Residents – Monthly IRCC Updates
# Temporary Residents: Study Permit Holders – Monthly IRCC Updates
# Transition from Temporary Resident to Permanent Resident Status – Monthly IRCC Updates
# Express Entry Permanent Residents – Monthly IRCC Updates
# Afghan Refugees (Permanent Resident Admissions) under Canada’s #WelcomeAfghans Commitment – Monthly IRCC Updates
# Operational Processing – Monthly IRCC Updates
# Temporary Residents: Temporary Foreign Worker Program (TFWP) and International Mobility Program (IMP) Work Permit Holders – Monthly IRCC Updates
# (ARCHIVED) Syrian Refugees – Monthly IRCC Updates
# (ARCHIVED) Resettled Refugees – Monthly IRCC Updates
# Facts & Figures 2015: Immigration Overview - Permanent Residents – Annual IRCC Updates
# Study Permit Extension Eligibility Model
# 2024-2025 Departmental Results Framework
# ...
