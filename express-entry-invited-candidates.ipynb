# %%
import gcinfo

gcinfo.list_resources(gcinfo.search_datasets(query='title:"Express Entry-Invited Candidates – Monthly IRCC Updates"')["results"][0])
# Out:
# === Express Entry-Invited Candidates – Monthly IRCC Updates ===
# ID: 593e9165-c6ce-4f9b-b519-03d315f92cd4
# Org: Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada
# Notes: Qualified people in the Express Entry pool who have been invited to apply for permanent residence status.
#
# Please note that in these datasets, the figures have been suppressed or rounded to prevent ...
# Citation: Citizenship and Immigration Canada. Express Entry-Invited Candidates – Monthly IRCC Updates
#   [XLSX    ] Canada - Express Entry Candidates by Province/Territory and Invitation Category
#            https://www.ircc.canada.ca/opendata-donneesouvertes/data/EN_ODP-EE_Candidates-IntDest.xlsx
#   [XLSX    ] Canada - Express Entry Candidates by Province/Territory and Invitation Category
#            https://www.ircc.canada.ca/opendata-donneesouvertes/data/FR_ODP-EE_Candidates-IntDest.xlsx
# ...
