# %%
import gcinfo
import pandas as pd
import matplotlib.pyplot as plt

gcinfo.search_titles("removals")
# Out:
# Removals Processed by Region by Year
# Land-based greenhouse gas emissions and removals
# Lyme disease video: How to properly remove a tick
# Laser Hair Removal - Safety Guidelines for Facility Owners and Operators
# Notice of Amendment: Tramadol removed from the Prescription Drug List (PDL)
# 2020 Spring Reports of the Auditor General of Canada—Report 1—Immigration Removals
# Removing educational barriers in South Sudan—and opening up a world of possibilities
# Security Considerations for the Use of Removable Media Devices for Protected C and Classified Information (ITSB-112)
# Summary Safety Review - ESSURE Permanent Birth Control System - Assessing the Risk of Complications and the Potential Need for Device Removal
# Business or organization barriers in purchasing technology-enabled carbon dioxide removal credits before the end of 2030, second quarter of 2026
# Businesses or organizations that are considering purchasing technology-enabled carbon dioxide removal credits before the end of 2030, second quarter of 2026
# Length of time businesses require before being able to return to normal operations once social distancing measures are removed, by business characteristics
# Briefing package - Appearance of the Auditor General of Canada before the Standing Committee on Public Accounts on Report 1—Immigration Removals, of the 2020 Spring Reports of the Auditor General of Canada –  24 November 2020
# Entries removed from the Ontario data catalogue
# Snow removal contracts and transactions
# Social Sciences and Humanities Research Council Accessibility Plan
# Flood cleanup: keep in mind indoor air quality
# Agreements Between Canada and the City of Nairobi
# Yukon Bathymetry Maps and Data
# Breast implants

# %%
gcinfo.list_resources(gcinfo.search_datasets(query='title:"Removals Processed by Region by Year"')["results"][0])
# Out:
# === Removals Processed by Region by Year ===
# ID: 87ccfc74-1065-4399-aeb7-34a07de25c0b
# Org: Canada Border Services Agency | Agence des services frontaliers du Canada
# Notes: This dataset represents the total number of persons removed by region in each of the calendar years 2009-2013....
# Citation: Canada Border Services Agency. Removals Processed by Region by Year
#   [CSV     ] Removals Completed by Region by Year
#            https://www.cbsa-asfc.gc.ca/data/remove-renvoi-eng.csv
#   [CSV     ] Removals Completed by Region by Year
#            https://www.cbsa-asfc.gc.ca/data/remove-renvoi-fra.csv

# %%
df = gcinfo.download_csv("https://www.cbsa-asfc.gc.ca/data/remove-renvoi-eng.csv")
df
# Out:
# Using cached file: cache\remove-renvoi-eng.csv
#                                     Removals Executed Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                             Regions       2009       2010
# 2                                International Region          5          7
# 3                                     Atlantic Region        112         85
# 4                                       Quebec Region      4,328      4,230
# 5                                      Ontario Region      7,864      8,231
# 6                                  Prairies/NT Region        734        707
# 7                       British Columbia/Yukon Region      1,816      2,118
# 8                             Total Removals Executed     14,859     15,378
# 9   Source: CIC DWS - Enforcement - Removals\nCrea...        NaN        NaN
# 10                                                NaN        NaN        NaN
# 11                                                NaN        NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0         NaN        NaN        NaN
# 1        2011       2012       2013
# 2          10          4          5
# 3         117        109        116
# 4       3,705      4,199      4,140
# 5       8,538     10,830      7,902
# 6         896      1,053        967
# 7       2,418      2,726      2,102
# 8      15,684     18,921     15,232
# 9         NaN        NaN        NaN
# 10        NaN        NaN        NaN
# 11        NaN        NaN        NaN
